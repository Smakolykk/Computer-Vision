# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('images/fruit.png')
plt.imshow(img)

# %%
img2 = img[:,:,::-1]
plt.imshow(img2)

# %%
red   = img2[:, :, 0]
green = img2[:, :, 1]
blue  = img2[:, :, 2]

# %%
plt.imshow(red, cmap='binary_r')

# %%
plt.imshow(green, cmap='binary_r')

# %%
plt.imshow(blue, cmap='binary_r')

# %%
green
# Out:
# array([[254, 255, 255, ..., 255, 255, 255],
#        [254, 255, 255, ..., 255, 255, 255],
#        [254, 255, 255, ..., 255, 255, 255],
#        ...,
#        [254, 255, 254, ..., 255, 254, 254],
#        [254, 255, 255, ..., 255, 255, 255],
#        [253, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
line = cv2.line(green.astype('float64'), (0,50), (634,45), (0, 255, 0), 2)

# %%
plt.imshow(line, cmap='binary_r')

# %%
plt.plot(green[45, :])

# %%
green[45, :]
# Out:
# array([254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
# ...
